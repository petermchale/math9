# %% [markdown]
# Hello. This is a notebook.

# %% [markdown]
# Convert a cell to a markdown cell by pressing escape followed by m.

# %% [markdown]
# To evaluate a cell press shift + enter

# %% [markdown]
# Each cell is a code or markdown cell.

# %%
This is a code cell
# Out:
#   File "<ipython-input-1-0a8c5a4a5842>", line 1
#     This is a code cell
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# Code cells are used to compute things

# %%
5*3
# Out:
# 15

# %%
# lines in code cells that start with a hash are ignored by Python
# 2 + 2

# %% [markdown]
# # Markdown format
#
# This is a way to format text easily.
