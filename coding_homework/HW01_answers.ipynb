# %% [markdown]
# Please fill this notebook with your code (remove `pass` after "# your code here"), execute all cells, save the notebook on your machine, and upload it to the [Math9 HW01 Dropbox](https://eee.uci.edu/toolbox/dropbox/) by the deadline indicated in the Dropbox. A primer on Dropbox is [here](https://eee.uci.edu/help/dropbox/instructors/_assets/dropbox_primer.pdf).

# %%
# libhw01 includes the drawing and graphing functions we are going to use
import libHW01 as hwlib
import math

def f(x):
    return math.sin(math.pi*x)

hwlib.graphfunction(f)

# %% [markdown]
# ### Problem 1
#
# Write the functions represented in the following graphs
# and use `graphfunction` to graph them.

# %%
from IPython.display import Image, display
display(Image("graph1.png", width=400))

def f(x):
    return math.sin(4*math.pi*x)
hwlib.graphfunction(f)

# %%
display(Image("graph2.png", width=400))

def f(x):
    return ((x))*math.sin(30*math.pi*x)
hwlib.graphfunction(f)

# %%
display(Image("graph3.png", width=400))

def f(x):
    if x>0.5:
        return 0.5
    if x<-0.5:
        return -0.5
    return x
hwlib.graphfunction(f)

# %% [markdown]
# ### Problem 2

# %% [markdown]
# How do we graph a function $f(x,y)$ in two variables? One way to do it is to consider the function’s value $f(x,y)$ at a point $(x,y)$ as the color-intensity at that point. So, for example, if $f(0,0) = 0$, then you put a black pixel at $(0,0)$, i.e. the center. If $f(1, 1) = 1$, then you put a white pixel at $(1,1)$, i.e. the top-right. Consider the following code and the output:

# %%
def g(x,y):
    return x**2 + y**2
hwlib.drawfunction(g)

# %% [markdown]
# Note that values above 1 are represented as white pixels, and the value 0 is represented using black pixels.
#
# Write down functions that will produce the following pictures:

# %%
display(Image("img1.png", width=300))

def g(x,y):
    return 1-abs(x)
hwlib.drawfunction(g)

# %%
display(Image("img2.png", width=300))

def g(x,y):
    return 1 if y > x else 0
hwlib.drawfunction(g)

# %%
display(Image("img3.png", width=300))

def g(x,y):
    return 1 if y > math.sin(10*x)/8 else 0
hwlib.drawfunction(g)

# %%
display(Image("img4.png", width=300))

def h(x,y): 
    return math.sqrt(x**2+y**2)

def g(x,y):
    if h(x,y)<0.2 or h(x,y)>0.8:
        return 1
    return 0
hwlib.drawfunction(g)

# %% [markdown]
# ### Problem 3
#
# Functions in python can be used as inputs to a function and can be returned from functions just like everything else. An example is the discussion of closures in Lecture02.ipynb.
# Another example is the function `rotateleft`:

# %%
def rotateleft(f):
    def g(x,y):
        return f(y, -x)
    return g

# %% [markdown]
# It takes in a function and returns a different function which we can then use.
#
# Now consider the function `fun` and its graph:

# %%
def fun(x,y):
    return abs(x+y)
hwlib.drawfunction(fun)

# %% [markdown]
# What will the following code output? (first guess then try running the code).

# %%
hwlib.drawfunction(rotateleft(fun))

# %% [markdown]
# Modify the code for `rotateleft` so that it rotates to the left by $\pi/3$ instead of $\pi/2$:

# %%
def rotateleft(f):
    # your code here
    pass
